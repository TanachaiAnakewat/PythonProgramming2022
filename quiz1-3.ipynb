# %% [markdown]
# # 教材1-3の練習
#
# [English version](https://colab.research.google.com/drive/1vC9u0dXzPqxJ_gV439M9O43S7mYKKBM2)

# %% [markdown]
# 模範解答は教材[1-3](https://utokyo-ipp.github.io/1/1-3.html)の末尾にあります。

# %% [markdown]
# ## Quiz1-3-1. absolute
#
# 数値 `x` の絶対値を求める関数 `absolute(x)` を定義してください。
# Pythonには `abs` という絶対値を求める組み込み関数が用意されていますが、それを使わずに定義してください。

# %%
##########################################################
##  <[ quiz1-3-1_absolute ]> 解答セル (Answer cell)
##  このコメントの書き変えを禁ず (Never edit this comment)
##########################################################

QUESTION_EXISTS = False # 質問がある場合は True に変えて，このセル内のコメントとして質問を記述してください
                        # Change to True if you have questions, and describe them as comments in this cell

def absolute(x):
    return x if x>0 else -x

# %% [markdown]
# 提出前に以下のテストセルを実行し、エラーがでないことを確認してください。

# %%
assert absolute(5) == 5
assert absolute(-5) == 5
assert absolute(0) == 0

# %% [markdown]
# ## Quiz1-3-2. sign
#
# `x` が正ならば 1、負ならば -1、ゼロならば 0 を返す関数 `sign(x)` を定義してください。

# %%
##########################################################
##  <[ quiz1-3-2_sign ]> 解答セル (Answer cell)
##  このコメントの書き変えを禁ず (Never edit this comment)
##########################################################

QUESTION_EXISTS = False # 質問がある場合は True に変えて，このセル内のコメントとして質問を記述してください
                        # Change to True if you have questions, and describe them as comments in this cell

def sign(x):
    if x>0:
      return 1
    elif x==0:
      return 0
    else:
      return -1

# %% [markdown]
# 提出前に以下のテストセルを実行し、エラーがでないことを確認してください。

# %%
assert sign(5) == 1
assert sign(-5) == -1
assert sign(0) == 0
